# %%
import csv
from collections import defaultdict
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests
import pandas as pd

# %%
Fams,species={},[]
for r in csv.reader(open('Orthogroups_JSD.tsv'),delimiter='\t'):
    if r[0]=="Orthogroup":
        species=r[1:]
        print(species)
        continue
    fid,glt=r[0],r[1:]
    #print(fid,'>>>',glt)
    gbs=defaultdict(list)
    gbs={species[i]:gs.split(',') for i,gs in enumerate(glt)}
    Fams[fid]=gbs
    #break
        #if i==5: break
#species=list(set(species))
# Out:
# ['Aque', 'Blan', 'Cele', 'Cgig', 'Chem', 'Ctel', 'Dgyr', 'Dmel', 'Drer', 'Eand', 'Hmia', 'Hrob', 'Hsap', 'Lana', 'Lgig', 'Lluy', 'Locu', 'Myes', 'Ngen', 'Nvec', 'Ofus', 'Paus', 'Skow', 'Smar', 'Smed', 'Spur', 'Tcas']

# %%
print(gbs)
# Out:
# {'Aque': [''], 'Blan': [''], 'Cele': [''], 'Cgig': [''], 'Chem': [''], 'Ctel': [''], 'Dgyr': [''], 'Dmel': [''], 'Drer': [''], 'Eand': [''], 'Hmia': [''], 'Hrob': [''], 'Hsap': [''], 'Lana': [''], 'Lgig': [''], 'Lluy': [''], 'Locu': [''], 'Myes': [''], 'Ngen': [''], 'Nvec': [''], 'Ofus': [''], 'Paus': [''], 'Skow': [''], 'Smar': [''], 'Smed': [''], 'Spur': [''], 'Tcas': ['Tcas_TC034497_001', ' Tcas_TC035044_001']}

# %%
genefam=defaultdict(dict)
for fid,gbs in Fams.items():
    for sp in gbs:
        for g in gbs[sp]:
            #genefam[sp][g.split('.',1)[0]]=fid
            genefam[sp][g]=fid

# %%
print(genefam.keys())
# Out:
# dict_keys(['Aque', 'Blan', 'Cele', 'Cgig', 'Chem', 'Ctel', 'Dgyr', 'Dmel', 'Drer', 'Eand', 'Hmia', 'Hrob', 'Hsap', 'Lana', 'Lgig', 'Lluy', 'Locu', 'Myes', 'Ngen', 'Nvec', 'Ofus', 'Paus', 'Skow', 'Smar', 'Smed', 'Spur', 'Tcas'])

# %%
print(list(genefam.items())[18:23])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def gbm(mods):
    gbms=defaultdict(list)
    for g,m in mods.items():
        gbms[m].append(g)
    return(gbms)

# %%
ctel_mods={r[0]:r[1] for r in csv.reader(open('03-Dimorphilus_gyrociliatus_mfuzz_clusters_TFonly.txt'),delimiter='\t')}

# %%
ofus_mods={r[0]:r[1] for r in csv.reader(open('03-Capitella_teleta_mfuzz_clusters_TFonly.txt'),delimiter='\t')}

# %%
ctel_gbm=gbm(ctel_mods)
ofus_gbm=gbm(ofus_mods)

# %%
def comp(gl1,gl2,pairs):
    p1={r[0]:r[1] for r in pairs}
    p2={r[1]:r[0] for r in pairs}
    rgl1=[g1 for g1 in gl1 if g1 in p1]
    rgl2=[g2 for g2 in gl2 if g2 in p2]

# %%
print(sum([1 for f,gbs in Fams.items() if 'Dgyr' in gbs and 'Ctel' in gbs]))
# Out:
', 'Dgyr_DgyrT3335', 'Dgyr_DgyrT3433', 'Dgyr_DgyrT3437', 'Dgyr_DgyrT3438', 'Dgyr_DgyrT3439', 'Dgyr_DgyrT3449', 'Dgyr_DgyrT3454', 'Dgyr_DgyrT3468', 'Dgyr_DgyrT3474', 'Dgyr_DgyrT3475', 'Dgyr_DgyrT3480', 'Dgyr_DgyrT3483', 'Dgyr_DgyrT3484', 'Dgyr_DgyrT3821', 'Dgyr_DgyrT3823', 'Dgyr_DgyrT3824', 'Dgyr_DgyrT3840', 'Dgyr_DgyrT3853', 'Dgyr_DgyrT4016', 'Dgyr_DgyrT4115', 'Dgyr_DgyrT4168', 'Dgyr_DgyrT4405', 'Dgyr_DgyrT4422', 'Dgyr_DgyrT4457', 'Dgyr_DgyrT4459', 'Dgyr_DgyrT4526', 'Dgyr_DgyrT4532', 'Dgyr_DgyrT4538', 'Dgyr_DgyrT4539', 'Dgyr_DgyrT4542', 'Dgyr_DgyrT4543', 'Dgyr_DgyrT4544', 'Dgyr_DgyrT4545', 'Dgyr_DgyrT4559', 'Dgyr_DgyrT4597', 'Dgyr_DgyrT4598', 'Dgyr_DgyrT4599', 'Dgyr_DgyrT4650', 'Dgyr_DgyrT47 ...

# %%
def ogcomp(gbm1,gbm2,genefam,nm1,nm2):
    res=[]
    nshog=sum([1 for f,gbs in Fams.items() if nm1 in gbs and nm2 in gbs])
    for m1,gl1 in gbm1.items():
        for m2,gl2 in gbm2.items():
            #print('pliv{} <-> spur{}'.format(m1,m2))
            rgl1=set([genefam[nm1][g1] for g1 in gl1 if g1 in genefam[nm1]])
            rgl2=set([genefam[nm2][g2] for g2 in gl2 if g2 in genefam[nm2]])
            gle=rgl1.union(rgl2)
            gli=rgl1.intersection(rgl2)
            # M : 
            hpd=stats.hypergeom(nshog, len(rgl1),len(rgl2))
            print(nshog,len(rgl1),len(rgl2),len(gli),hpd.pmf(len(gli)))
            rep=round(len(gli)/(len(rgl2)*len(rgl1)/nshog),3)
            # (n * D) / N
            #print(len(p1),len(rgl1),len(rgl2),len(gli),hpd.pmf(len(gli)),rep)
            res.append(['{}{}'.format(nm1,m1),'{}{}'.format(nm2,m2),len(rgl1),len(rgl2),len(gli),hpd.pmf(len(gli)),rep])
            phyper=pd.DataFrame(res, columns = ['cl1','cl2','no1','no2','nov','pv','rf'])  
    return(phyper)

# %%
def comp(gbm1,gbm2,pairs,nm1,nm2):
    res=[]
    for m1,gl1 in gbm1.items():
        for m2,gl2 in gbm2.items():
            #print('pliv{} <-> spur{}'.format(m1,m2))
            p1={r[0]:r[1] for r in pairs}
            p2={r[1]:r[0] for r in pairs}
            rgl1=[g1 for g1 in gl1 if g1 in p1]
            rgl2=[g2 for g2 in gl2 if g2 in p2]
            gle=set([p2[g2] for g2 in gl2 if g2 in p2]+rgl1)
            gli=[g1 for g1 in rgl1 for g2 in rgl2 if p1[g1]==g2]
            hpd=stats.hypergeom(len(p1), len(rgl1),len(rgl2))
            rep=round(len(gli)/(len(rgl2)*len(rgl1)/len(p1)),3)# (n * D) / N
            #print(len(p1),len(rgl1),len(rgl2),len(gli),hpd.pmf(len(gli)),rep)
            res.append(['{}{}'.format(nm1,m1),'{}{}'.format(nm2,m2),len(rgl1),len(rgl2),len(gli),hpd.pmf(len(gli)),rep])
    phyper=pd.DataFrame(res, columns = ['cl1','cl2','no1','no2','nov','pv','rf'])  
    return(phyper)

# %%
ctel_ofus_hyp=ogcomp(ctel_gbm,ofus_gbm,genefam,'Dgyr','Ctel')
# Out:
# 54440 588 66 13 2.7775083004866625e-13
# 54440 588 10 1 0.0979673503302318
# 54440 588 25 10 5.576483369473036e-14
# 54440 588 26 1 0.2141405510728038
# 54440 588 48 8 4.342159979729916e-08
# 54440 588 44 20 4.625666587097127e-28
# 54440 588 50 5 0.00018859475265549502
# 54440 588 15 2 0.010623447713218886
# 54440 588 24 8 1.094570749351849e-10
# 54440 588 28 4 0.00021292148911312823
# 54440 588 8 0 0.9167846339410419
# 54440 588 16 2 0.012010358715023126
# 54440 433 66 2 0.08137806197161508
# 54440 433 10 0 0.9232439964356514
# 54440 433 25 1 0.1642291035868069
# 54440 433 26 0 0.8124741845736575
# 54440 433 48 1 0.26249315573522586
# 54440 433 44 0 0.703630559990287
# 54440 433 50 1 0.2691042227848135
# 54440 433 15 1 0.10671219075583083
# 54440 433 24 0 0.8255603603491628
# 54440 433 28 0 0.7995949697591356
# 54440 433 8 0 0.938109870678075
# 54440 433 16 0 0.8800418323847522
# 54440 393 66 2 0.07027564037881207
# 54440 393 10 0 0.9301053633936907
# 54440 393 25 0 0.8342947118343832
# 54440 393 26 1 0.15666311431634158
# 54440 393 48 0 0.706157171230911
# 54440 393 44 0 0.7269391124819485
# 54440 393 50 1 0.25327222991705345
# 54440 393 15 0 0.8970074440104294
# 54440 393 24 0 0.840363938307384
# 54440 393 28 1 0.1662920142032955
# 54440 393 8 0 0.9436831121604803
# 54440 393 16 1 0.10363588071543557
# 54440 412 66 2 0.0755242896551149
# 54440 412 10 1 0.07068962609877348
# 54440 412 25 1 0.15772931128693513
# 54440 412 26 5 1.361541074636069e-06
# 54440 412 48 1 0.2543700942802712
# 54440 412 44 2 0.03934163672023043
# 54440 412 50 0 0.6838552200022564
# 54440 412 15 2 0.00543766999990568
# 54440 412 24 1 0.15257250763577943
# 54440 412 28 2 0.017742625203271977
# 54440 412 8 0 0.9410322206371831
# 54440 412 16 2 0.006167664440866834
# 54440 482 66 3 0.018081528212747274
# 54440 482 10 0 0.9149009225023835
# 54440 482 25 1 0.1788735856117061
# 54440 482 26 3 0.0014634454853075607
# 54440 482 48 1 0.2799892558456803
# 54440 482 44 3 0.006357583606384288
# 54440 482 50 1 0.28651989347016216
# 54440 482 15 1 0.11728799866022309
# 54440 482 24 3 0.0011595605596177126
# 54440 482 28 0 0.779523868130666
# 54440 482 8 0 0.9313219152588851
